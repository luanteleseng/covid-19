# %% [markdown]
# # Coronavirus Pandemic in Brazil
# ### Project Data - 07/26/2021
#
#
# - New Cases
# - New Deaths
# - Vaccination
#
# [1] Mathieu, E., Ritchie, H., Ortiz-Ospina, E. et al - A global database of COVID-19 vaccinations (2021). https://ourworldindata.org/covid-vaccinations?country=BRA<p><p>
#
# Last Update: 10/06/2021 - 01:51:28  (24 hour format, in UTC)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Data

# %%
url_data = 'https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data.csv?raw=true'

df = pd.read_csv(url_data)
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df_brazil = df.loc[df['location'] == 'Brazil']
df_brazil.head()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 20990      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 20991      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 20992      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 20993      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 20994      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 20990                 NaN           NaN         NaN                  NaN  ...
# 20991                 NaN           NaN         NaN                  NaN  ...
# 20992                 NaN           NaN         NaN                  NaN  ...
# 20993                 NaN           NaN         NaN                  NaN  ...
# 20994                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 20990            10.1          17.9                     NaN
# 20991            10.1          17.9                     NaN
# 20992            10.1          17.9                     NaN
# 20993            10.1          17.9                     NaN
# 20994            10.1          17.9                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 20990                         2.2            75.88                    0.765
# 20991                         2.2            75.88                    0.765
# 20992                         2.2            75.88                    0.765
# 20993                         2.2            75.88                    0.765
# 20994                         2.2            75.88                    0.765
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 20990                                   NaN                          NaN
# 20991                                   NaN                          NaN
# 20992                                   NaN                          NaN
# 20993                                7049.6                         3.31
# 20994                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 20990               NaN                                      NaN
# 20991               NaN                                      NaN
# 20992               NaN                                      NaN
# 20993              5.25                                32.943066
# 20994               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df_brazil.shape
# Out:
# (728, 67)

# %%
df_brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 728 entries, 20990 to 21717
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    728 non-null    object
#  1   continent                                   728 non-null    object
#  2   location                                    728 non-null    object
#  3   date                                        728 non-null    object
#  4   total_cases                                 728 non-null    float64
#  5   new_cases                                   727 non-null    float64
#  6   new_cases_smoothed                          722 non-null    float64
#  7   total_deaths                                708 non-null    float64
#  8   new_deaths                                  708 non-null    float64
#  9   new_deaths_smoothed                         708 non-null    float64
#  10  total_cases_per_million                     728 non-null    float64
#  11  new_cases_per_million                       727 non-null    float64
#  12  new_cases_smoothed_per_million              722 non-null    float64
#  13  total_deaths_per_million                    708 non-null    float64
#  14  new_deaths_per_million                      708 non-null    float64
#  15  new_deaths_smoothed_per_million             708 non-null    float64
#  16  reproduction_rate                           707 non-null    float64
#  17  icu_patients                                0 non-null      float64
#  18  icu_patients_per_million                    0 non-null      float64
#  19  hosp_patients                               0 non-null      float64
#  20  hosp_patients_per_million                   0 non-null      float64
#  21  weekly_icu_admissions                       0 non-null      float64
#  22  weekly_icu_admissions_per_million           0 non-null      float64
#  23  weekly_hosp_admissions                      0 non-null      float64
#  24  weekly_hosp_admissions_per_million          0 non-null      float64
#  25  new_tests                                   265 non-null    float64
#  26  total_tests                                 359 non-null    float64
#  27  total_tests_per_thousand                    359 non-null    float64
#  28  new_tests_per_thousand                      265 non-null    float64
#  29  new_tests_smoothed                          654 non-null    float64
#  30  new_tests_smoothed_per_thousand             654 non-null    float64
#  31  positive_rate                               0 non-null      float64
#  32  tests_per_case                              0 non-null      float64
#  33  tests_units                                 661 non-null    object
#  34  total_vaccinations                          396 non-null    float64
#  35  people_vaccinated                           392 non-null    float64
#  36  people_fully_vaccinated                     376 non-null    float64
#  37  total_boosters                              168 non-null    float64
#  38  new_vaccinations                            393 non-null    float64
#  39  new_vaccinations_smoothed                   401 non-null    float64
#  40  total_vaccinations_per_hundred              396 non-null    float64
#  41  people_vaccinated_per_hundred               392 non-null    float64
#  42  people_fully_vaccinated_per_hundred         376 non-null    float64
#  43  total_boosters_per_hundred                  168 non-null    float64
#  44  new_vaccinations_smoothed_per_million       401 non-null    float64
#  45  new_people_vaccinated_smoothed              401 non-null    float64
#  46  new_people_vaccinated_smoothed_per_hundred  401 non-null    float64
#  47  stringency_index                            718 non-null    float64
#  48  population                                  728 non-null    float64
#  49  population_density                          728 non-null    float64
#  50  median_age                                  728 non-null    float64
#  51  aged_65_older                               728 non-null    float64
#  52  aged_70_older                               728 non-null    float64
#  53  gdp_per_capita                              728 non-null    float64
#  54  extreme_poverty                             728 non-null    float64
#  55  cardiovasc_death_rate                       728 non-null    float64
#  56  diabetes_prevalence                         728 non-null    float64
#  57  female_smokers                              728 non-null    float64
#  58  male_smokers                                728 non-null    float64
#  59  handwashing_facilities                      0 non-null      float64
#  60  hospital_beds_per_thousand                  728 non-null    float64
#  61  life_expectancy                             728 non-null    float64
#  62  human_development_index                     728 non-null    float64
#  63  excess_mortality_cumulative_absolute        24 non-null     float64
#  64  excess_mortality_cumulative                 24 non-null     float64
#  65  excess_mortality                            24 non-null     float64
#  66  excess_mortality_cumulative_per_million     24 non-null     float64
# dtypes: float64(62), object(5)
# memory usage: 386.8+ KB

# %%
df_brazil_vac = df_brazil.loc[df['people_vaccinated'] >= 1]
df_brazil_vac[['date','people_vaccinated']]
# Out:
#              date  people_vaccinated
# 21316  2021-01-17              112.0
# 21317  2021-01-18             1109.0
# 21318  2021-01-19            13527.0
# 21319  2021-01-20           105824.0
# 21320  2021-01-21           193699.0
# ...           ...                ...
# 21713  2022-02-18        175933938.0
# 21714  2022-02-19        176141497.0
# 21715  2022-02-20        176222268.0
# 21716  2022-02-21        176406587.0
# 21717  2022-02-22        176625569.0
#
# [392 rows x 2 columns]

# %% [markdown]
# ## Data Visualization

# %%
# vaccinations
plt.figure(figsize=(16.3,5))
plt.title('People Vaccinated')
plt.xticks(range(1, (np.size(df_brazil_vac['date']) + 1), 25))

plt.plot(df_brazil_vac['date'], df_brazil_vac['people_vaccinated'], c='darkgreen', label='People Vaccinated')
plt.plot(df_brazil_vac['date'], df_brazil_vac['people_fully_vaccinated'], c='yellowgreen', label='People Fully Vaccinated')

plt.legend()
plt.show()

# %%
# statistics

br_vac = max(df_brazil_vac['people_vaccinated'])
br_fully_vac = df_brazil_vac['people_fully_vaccinated']
br_fully_vac = max(br_fully_vac.dropna())
br_pop = 213317639 #Brazil IBGE 2021 - population

print(f'People Vaccinated: {round((br_vac/br_pop)*100, 2)}%\nPeople Fully Vaccinated: {round((br_fully_vac/br_pop)*100, 2)}%')
# Out:
# People Vaccinated: 82.8%
# People Fully Vaccinated: 72.09%

# %%
# cases
plt.figure(figsize=(16.3,5))
plt.title('New cases')

plt.xticks(range(1, (np.size(df_brazil['date']) + 1), 70))

plt.bar(df_brazil['date'], df_brazil['new_cases'], color='darkgray')

plt.show()

# %%
# deaths
plt.figure(figsize=(16.3,5))
plt.title('Deaths')

plt.xticks(range(30, (np.size(df_brazil['date']) + 1), 60))

plt.bar(df_brazil['date'], df_brazil['new_deaths'], color='darkgray')

plt.show()

# %% [markdown]
# ## UTC Time Now

# %%
from datetime import datetime

now = datetime.utcnow()
print(f'Last Update: {now}')
# Out:
# Last Update: 2022-02-23 13:16:30.999793
